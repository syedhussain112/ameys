# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns 
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('VehicleData_csv.csv')

# %%
data_new = data[data != '2000-']

year_counts = dict(data['FinancialYear'].value_counts())
year = list(year_counts.keys())
count = list(year_counts.values())
plt.bar(year,count)
plt.show()

# %%
data_year = data.groupby(['FinancialYear'])

avg_year = dict(data_year['ConditionScore'].mean())
std_year = dict(data_year['ConditionScore'].std())
year = list(avg_year.keys())
score = list(std_year.values())

avg_overall = data['ConditionScore'].mean()
std_overall = data['ConditionScore'].std()

# %%
plt.scatter(year,score)
plt.ylim(0, 30)
plt.show()

# %%
data_type = data.groupby(['VehicleType'])
avg_type = dict(data_type['ConditionScore'].mean())

# %%
boxplot_year = data_year.boxplot(column = ['ConditionScore'])

# %%
boxplot_total = data.boxplot(column=['ConditionScore'])
